# %% [markdown]
# # Getting started with ML Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load some tabular data

# %%
data = pd.read_csv("./data/people-example.csv")

# %% [markdown]
# ## Pandas dataframe

# %%
data
# Out:
#    First Name   Last Name         Country  age
# 0         Bob       Smith   United States   24
# 1       Alice    Williams          Canada   23
# 2     Malcolm        Jone         England   22
# 3       Felix       Brown             USA   23
# 4        Alex      Cooper          Poland   23
# 5         Tod    Campbell   United States   22
# 6       Derek        Ward     Switzerland   25
# 7   Alexandra     Sanchez          Mexico   21
# 8      Martin       Silva        Portugal   27
# 9        Karl     Schmidt        Germainy   20
# 10       John       Smith         England   29
# 11       Jane     Johnson             USA   24
# 12        Ewa  Roszkowski          Poland   23
# 13        Sam     Sanders   United States   22
# 14     Gustav  Gustaffson     Switzerland   23
# 15       Jose    Martinez          Mexico   23
# 16      Diogo      Santos        Portugal   22
# 17      Maria       Sousa          Brazil   23
# 18     Sandra       Filva        Portugal   22
# 19      Karla    Oliveira          Brazil   21
# 20      Mario        Diaz          Brasil   28
# 21    Hillary       Meier     Switzerland   24
# 22    Jinglan        Shih             USA   27
# 23        Hoy      Jenson   United States   22
# 24      Miles        Ruiz          Brazil   21
# 25     Carlos      Alonso          Brazil   28
# 26      Steve        Gold   United States   24
# 27  Elizabeth       Gould         England   20
# 28      Susan     Sarason             USA   21
# 29       Eric     Nowicki          Poland   28
# 30       Erin      Taylor   United States   24
# 31   Maricota      Forres          Brazil   23
# 32    Natalia    Lisowski          Poland   22
# 33   Gabriela       Costa        Portugal   23
# 34      Joana     Sanchez          Mexico   21
# 35      Chase        Gray  Unisted States   27
# 36       Luca       Meier     Switzerland   25
# 37    Charles      Murphy          Canada   23
# 38  Elizabeth      Taylor         Englanf   24
# 39      Katie       Huges             USA   24
# 40        Sam       Nowak          Poland   20
# 41      Paige      Tucker   United States   21
# 42       Nina       Smith     Switzerland   28

# %%
data.tail()
# Out:
#    First Name Last Name        Country  age
# 38  Elizabeth    Taylor        Englanf   24
# 39      Katie     Huges            USA   24
# 40        Sam     Nowak         Poland   20
# 41      Paige    Tucker  United States   21
# 42       Nina     Smith    Switzerland   28

# %% [markdown]
# ## A few visualizations with datarames

# %%
def show_figure(keyword):
    plt.hist(data[keyword], 10)
    plt.title(keyword+' Histogram')
    plt.xlabel(keyword)
    plt.ylabel('Count')
    plt.show()

# %%
show_figure('age')

# %% [markdown]
# ## Inspect the columns of the dataset

# %%
data['Country']
# Out:
# 0      United States
# 1             Canada
# 2            England
# 3                USA
# 4             Poland
# 5      United States
# 6        Switzerland
# 7             Mexico
# 8           Portugal
# 9           Germainy
# 10           England
# 11               USA
# 12            Poland
# 13     United States
# 14       Switzerland
# 15            Mexico
# 16          Portugal
# 17            Brazil
# 18          Portugal
# 19            Brazil
# 20            Brasil
# 21       Switzerland
# 22               USA
# 23     United States
# 24            Brazil
# 25            Brazil
# 26     United States
# 27           England
# 28               USA
# 29            Poland
# 30     United States
# 31            Brazil
# 32            Poland
# 33          Portugal
# 34            Mexico
# 35    Unisted States
# 36       Switzerland
# 37            Canada
# 38           Englanf
# 39               USA
# 40            Poland
# 41     United States
# 42       Switzerland
# Name: Country, dtype: object

# %%
data['age']
# Out:
# 0     24
# 1     23
# 2     22
# 3     23
# 4     23
# 5     22
# 6     25
# 7     21
# 8     27
# 9     20
# 10    29
# 11    24
# 12    23
# 13    22
# 14    23
# 15    23
# 16    22
# 17    23
# 18    22
# 19    21
# 20    28
# 21    24
# 22    27
# 23    22
# 24    21
# 25    28
# 26    24
# 27    20
# 28    21
# 29    28
# 30    24
# 31    23
# 32    22
# 33    23
# 34    21
# 35    27
# 36    25
# 37    23
# 38    24
# 39    24
# 40    20
# 41    21
# 42    28
# Name: age, dtype: int64

# %%
data['age'].mean()
# Out:
# 23.488372093023255

# %%
data['age'].max()
# Out:
# 29

# %% [markdown]
# ## Create a new column

# %%
data
# Out:
#    First Name   Last Name         Country  age
# 0         Bob       Smith   United States   24
# 1       Alice    Williams          Canada   23
# 2     Malcolm        Jone         England   22
# 3       Felix       Brown             USA   23
# 4        Alex      Cooper          Poland   23
# 5         Tod    Campbell   United States   22
# 6       Derek        Ward     Switzerland   25
# 7   Alexandra     Sanchez          Mexico   21
# 8      Martin       Silva        Portugal   27
# 9        Karl     Schmidt        Germainy   20
# 10       John       Smith         England   29
# 11       Jane     Johnson             USA   24
# 12        Ewa  Roszkowski          Poland   23
# 13        Sam     Sanders   United States   22
# 14     Gustav  Gustaffson     Switzerland   23
# 15       Jose    Martinez          Mexico   23
# 16      Diogo      Santos        Portugal   22
# 17      Maria       Sousa          Brazil   23
# 18     Sandra       Filva        Portugal   22
# 19      Karla    Oliveira          Brazil   21
# 20      Mario        Diaz          Brasil   28
# 21    Hillary       Meier     Switzerland   24
# 22    Jinglan        Shih             USA   27
# 23        Hoy      Jenson   United States   22
# 24      Miles        Ruiz          Brazil   21
# 25     Carlos      Alonso          Brazil   28
# 26      Steve        Gold   United States   24
# 27  Elizabeth       Gould         England   20
# 28      Susan     Sarason             USA   21
# 29       Eric     Nowicki          Poland   28
# 30       Erin      Taylor   United States   24
# 31   Maricota      Forres          Brazil   23
# 32    Natalia    Lisowski          Poland   22
# 33   Gabriela       Costa        Portugal   23
# 34      Joana     Sanchez          Mexico   21
# 35      Chase        Gray  Unisted States   27
# 36       Luca       Meier     Switzerland   25
# 37    Charles      Murphy          Canada   23
# 38  Elizabeth      Taylor         Englanf   24
# 39      Katie       Huges             USA   24
# 40        Sam       Nowak          Poland   20
# 41      Paige      Tucker   United States   21
# 42       Nina       Smith     Switzerland   28

# %%
data['full name'] = data['First Name'] + ' ' + data['Last Name']

# %%
data
# Out:
#    First Name   Last Name         Country  age          full name
# 0         Bob       Smith   United States   24          Bob Smith
# 1       Alice    Williams          Canada   23     Alice Williams
# 2     Malcolm        Jone         England   22       Malcolm Jone
# 3       Felix       Brown             USA   23        Felix Brown
# 4        Alex      Cooper          Poland   23        Alex Cooper
# 5         Tod    Campbell   United States   22       Tod Campbell
# 6       Derek        Ward     Switzerland   25         Derek Ward
# 7   Alexandra     Sanchez          Mexico   21  Alexandra Sanchez
# 8      Martin       Silva        Portugal   27       Martin Silva
# 9        Karl     Schmidt        Germainy   20       Karl Schmidt
# 10       John       Smith         England   29         John Smith
# 11       Jane     Johnson             USA   24       Jane Johnson
# 12        Ewa  Roszkowski          Poland   23     Ewa Roszkowski
# 13        Sam     Sanders   United States   22        Sam Sanders
# 14     Gustav  Gustaffson     Switzerland   23  Gustav Gustaffson
# 15       Jose    Martinez          Mexico   23      Jose Martinez
# 16      Diogo      Santos        Portugal   22       Diogo Santos
# 17      Maria       Sousa          Brazil   23        Maria Sousa
# 18     Sandra       Filva        Portugal   22       Sandra Filva
# 19      Karla    Oliveira          Brazil   21     Karla Oliveira
# 20      Mario        Diaz          Brasil   28         Mario Diaz
# 21    Hillary       Meier     Switzerland   24      Hillary Meier
# 22    Jinglan        Shih             USA   27       Jinglan Shih
# 23        Hoy      Jenson   United States   22         Hoy Jenson
# 24      Miles        Ruiz          Brazil   21         Miles Ruiz
# 25     Carlos      Alonso          Brazil   28      Carlos Alonso
# 26      Steve        Gold   United States   24         Steve Gold
# 27  Elizabeth       Gould         England   20    Elizabeth Gould
# 28      Susan     Sarason             USA   21      Susan Sarason
# 29       Eric     Nowicki          Poland   28       Eric Nowicki
# 30       Erin      Taylor   United States   24        Erin Taylor
# 31   Maricota      Forres          Brazil   23    Maricota Forres
# 32    Natalia    Lisowski          Poland   22   Natalia Lisowski
# 33   Gabriela       Costa        Portugal   23     Gabriela Costa
# 34      Joana     Sanchez          Mexico   21      Joana Sanchez
# 35      Chase        Gray  Unisted States   27         Chase Gray
# 36       Luca       Meier     Switzerland   25         Luca Meier
# 37    Charles      Murphy          Canada   23     Charles Murphy
# 38  Elizabeth      Taylor         Englanf   24   Elizabeth Taylor
# 39      Katie       Huges             USA   24        Katie Huges
# 40        Sam       Nowak          Poland   20          Sam Nowak
# 41      Paige      Tucker   United States   21       Paige Tucker
# 42       Nina       Smith     Switzerland   28         Nina Smith

# %%
data['age'] * data['age']
# Out:
# 0     576
# 1     529
# 2     484
# 3     529
# 4     529
# 5     484
# 6     625
# 7     441
# 8     729
# 9     400
# 10    841
# 11    576
# 12    529
# 13    484
# 14    529
# 15    529
# 16    484
# 17    529
# 18    484
# 19    441
# 20    784
# 21    576
# 22    729
# 23    484
# 24    441
# 25    784
# 26    576
# 27    400
# 28    441
# 29    784
# 30    576
# 31    529
# 32    484
# 33    529
# 34    441
# 35    729
# 36    625
# 37    529
# 38    576
# 39    576
# 40    400
# 41    441
# 42    784
# Name: age, dtype: int64

# %% [markdown]
# ## Create a complex trandataormation of our data using a lambda function

# %%
show_figure('Country')

# %%
def trandataorm_country(country):
    if country == 'USA':
        return 'United States'
    else:
        return country

# %%
trandataorm_country('Brazil')
# Out:
# 'Brazil'

# %%
trandataorm_country('Brasil')
# Out:
# 'Brasil'

# %%
trandataorm_country('USA')
# Out:
# 'United States'

# %%
data['Country'] = data['Country'].apply(trandataorm_country)

# %%
show_figure('Country')
